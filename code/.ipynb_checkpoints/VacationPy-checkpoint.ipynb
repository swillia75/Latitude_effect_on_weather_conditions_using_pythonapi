# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_data = pd.read_csv("city_weather_data.csv")

city_data.head()
# Out:
#    Unnamed: 0                City    Lat     Lon  Max Temp (F)  Humidity (%)  \
# 0           0  São Félix do Xingu  -6.64  -51.99         88.27            48
# 1           1               Airai  -8.93  125.41         55.80           100
# 2           2     Tiznit Province  29.58   -9.50         71.40            59
# 3           3           Cape Town -33.93   18.42         61.00            71
# 4           4           Hithadhoo  -0.60   73.08         84.83            73
#
#    Cloudiness (%)  Wind Speed (MPH) Country        Date
# 0              28              4.16      BR  1593285655
# 1              86              3.15      TL  1593285629
# 2               0              3.49      MA  1593286215
# 3              75              6.93      ZA  1593285481
# 4              44              8.19      MV  1593285642

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = city_data[["Lat", "Lon"]].astype(float)
humidity = city_data["Humidity (%)"].astype(float)

# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Narrowing database to max_temp between 70 and 80, Wind Speed <10, and zero cloudiness

ideal_weather = city_data.loc[(city_data["Max Temp (F)"] > 70) &
                             (city_data["Max Temp (F)"] < 80) &
                             (city_data["Wind Speed (MPH)"] < 10) &
                             (city_data["Cloudiness (%)"] == 0)]
                              
                              # just in case added condition to drop choices to 10
 #                            (city_data["Humidity (%)"] <=80)]
#Choosing wanted columns 
hotel_df = ideal_weather[["City", "Lat", "Lon", "Max Temp (F)", "Humidity (%)", 
                          "Cloudiness (%)", "Wind Speed (MPH)", "Country", "Date"]]
hotel_df
# Out:
#                    City    Lat    Lon  Max Temp (F)  Humidity (%)  \
# 2       Tiznit Province  29.58  -9.50         71.40            59
# 12            Mahajanga -15.72  46.32         71.60            88
# 35       Zabul Province  32.25  67.25         73.04            18
# 66           Kiryat Gat  31.61  34.76         79.00            87
# 133          Nikolskoye  59.70  30.79         71.60            49
# 175              Boueni -12.90  45.08         75.20            83
# 202               Erzin  36.96  36.20         77.00            89
# 213         Mitsamiouli -11.38  43.28         77.74            78
# 304  Nizhniy Baskunchak  48.22  46.83         72.48            36
# 320                Wete  -5.06  39.73         74.77            86
# 429               Kumul  42.80  93.45         76.06            34
# 496                Gaza  31.50  34.47         79.00            69
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date
# 2                 0              3.49      MA  1593286215
# 12                0              2.24      MG  1593286216
# 35                0              8.12      AF  1593286218
# 66                0              4.43      IL  1593285627
# 133               0              4.47      RU  1593286232
# 175               0              8.05      YT  1593286237
# 202               0              0.54      TR  1593286241
# 213               0              5.48      KM  1593286242
# 304               0              6.44      RU  1593286253
# 320               0              8.28      TZ  1593286255
# 429               0              5.57      CN  1593286272
# 496               0              3.36      PS  1593286282

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                    City    Lat    Lon  Max Temp (F)  Humidity (%)  \
# 2       Tiznit Province  29.58  -9.50         71.40            59
# 12            Mahajanga -15.72  46.32         71.60            88
# 35       Zabul Province  32.25  67.25         73.04            18
# 66           Kiryat Gat  31.61  34.76         79.00            87
# 133          Nikolskoye  59.70  30.79         71.60            49
# 175              Boueni -12.90  45.08         75.20            83
# 202               Erzin  36.96  36.20         77.00            89
# 213         Mitsamiouli -11.38  43.28         77.74            78
# 304  Nizhniy Baskunchak  48.22  46.83         72.48            36
# 320                Wete  -5.06  39.73         74.77            86
# 429               Kumul  42.80  93.45         76.06            34
# 496                Gaza  31.50  34.47         79.00            69
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date Hotel Name
# 2                 0              3.49      MA  1593286215
# 12                0              2.24      MG  1593286216
# 35                0              8.12      AF  1593286218
# 66                0              4.43      IL  1593285627
# 133               0              4.47      RU  1593286232
# 175               0              8.05      YT  1593286237
# 202               0              0.54      TR  1593286241
# 213               0              5.48      KM  1593286242
# 304               0              6.44      RU  1593286253
# 320               0              8.28      TZ  1593286255
# 429               0              5.57      CN  1593286272
# 496               0              3.36      PS  1593286282

# %%
# geocoordinates


target_radius = 5000
target_type = "lodging"

# set up a parameters dictionary
params = {
         "radius": target_radius,
         "types": target_type,
         "key": g_key,
          }

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    
    lat = row["Lat"]
    lon = row["Lon"]
    
    # add keyword to params dict
    params['location'] = f"{lat},{lon}"

    # assemble url and make API request
    
    
    response = requests.get(base_url, params=params).json()
    
    try:
               
        hotel_df.loc[index, 'Hotel Name'] = response["results"][0]['name']
        
    except :
        
        print("Missing field/result... skipping.")
# Out:
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAACNwHa87RH8ApUZTpE5ITGDZO3cl5_vSpuCwkUTgeyxx4t5w1QPRDs4wcNIkFGOgDJKEKnjsFZ-j8JJ9d7HNqABIIP5pDlhXaOur7JNYaCXLZizbsYi3Ajmnpl4dnsdJ4_T0vN9h2Jb8m8LdPNzdYTWMeOEbQibevwfubYn43GqiGIvv_qDcu7R958RLLTOvnHcNTH6vHzWrzQRwzVMh2Snee-chrulUp_8gs8bA8N2Fz0YEg7ntW6xBDZ_9IoiFslmkrOOARQeaXLjhiYFcedmuU7K-irm5qvEdBVsNXg7B8fx96xnI1_eqvKONzGPfDYaq8QL821JkVXC0nVqaQo4xW1qvxmETxjtp1TnrJhajDUvknWMaJ-qOsL154gjCTxIQoE9gyFJKj9ulrtrQJ2vz2xoUuP5hB0cbDDvP9xu6SewZPDfBxec',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5211719, 'lng': 34.4472038},
#     'viewport': {'northeast': {'lat': 31.5225545802915,
#       'lng': 34.4485136802915},
#      'southwest': {'lat': 31.5198566197085, 'lng': 34.4458157197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '2dc930633eac6827b870f8883146ff27448e1834',
#    'name': 'رابطة الفنانين الفلسطينيين',
#    'place_id': 'ChIJWwIK1hZ__RQRVhskkD4mrDc',
#    'plus_code': {'global_code': '8G3PGCCW+FV'},
#    'rating': 3.6,
#    'reference': 'ChIJWwIK1hZ__RQRVhskkD4mrDc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 55,
#    'vicinity': 'شارع الوحدة - تقاطع شارع عبد القادر الحسيني - مجمع عجور التجاري 2 - الطابق 4'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.52690650000001,
#      'lng': 34.43753999999999},
#     'viewport': {'northeast': {'lat': 31.5283381302915,
#       'lng': 34.4387341802915},
#      'southwest': {'lat': 31.52564016970851, 'lng': 34.4360362197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd253ffd4622ee4467265204189122903482d533c',
#    'name': 'فندق جراند بالاس Grand Palace Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 719,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110637368331949683563">فندق جراند بالاس Grand Palace Hotel</a>'],
#      'photo_reference': 'CmRaAAAAzS7FFclimokqF3RKIjTYI8zhqoocvwI9SMZl83PoW4VyErORz-0W1V8YEeNqjUNRz8GuvvnTC5HenEr9EVbFhbvprvrIqCs0UGhxxND3iIOtUd123MGP5uaKZZsxnEkDEhA_reSgAuHxAOzZXZNOir17GhQBsJsa-POgWvbPtXsjIgsFYurw6A',
#      'width': 1279}],
#    'place_id': 'ChIJJ9WRSCN__RQRA63y4WtNu5k',
#    'plus_code': {'global_code': '8G3PGCGQ+Q2'},
#    'rating': 3.6,
#    'reference': 'ChIJJ9WRSCN__RQRA63y4WtNu5k',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 91,
#    'vicinity': 'Al Rasheed street، غزة'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5016951, 'lng': 34.4668445},
#     'viewport': {'northeast': {'lat': 31.50305333029149,
#       'lng': 34.4681848802915},
#      'southwest': {'lat': 31.50035536970849, 'lng': 34.4654869197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd1dbfc0b77a2ebd2e7c21ab0f5a819cf59d9bb79',
#    'name': 'منزل أبناء المرحوم الشيخ حسن لبد',
#    'place_id': 'ChIJP725mzR__RQRv-2L4bk8GpQ',
#    'plus_code': {'global_code': '8G3PGF28+MP'},
#    'rating': 5,
#    'reference': 'ChIJP725mzR__RQRv-2L4bk8GpQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'غزة،'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5016951, 'lng': 34.4668445},
#     'viewport': {'northeast': {'lat': 31.50305333029149,
#       'lng': 34.4681848802915},
#      'southwest': {'lat': 31.50035536970849, 'lng': 34.4654869197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '947268c15a55a0d32bfc6b6efd5c2766283ef0b3',
#    'name': 'صالون NEXT',
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106242374763364282458">بلال حموده</a>'],
#      'photo_reference': 'CmRaAAAAWqrXshHnebs4TveNzP_tFLUCtD8cKeyEOzYvoo95PtBQu62rJjmr3Ntq5HCQO1k7iFfSUaLGx6pXEqM0OapwN5KRhJHQpJSWU8aQd-FGLcJ9_dslTKkqgdxP0vGB5NHxEhDjcJREnPGlH8ZIzmjw-TjIGhQBYVPk6eZb7Dq6YE32q6RPiiSnGw',
#      'width': 3456}],
#    'place_id': 'ChIJFxrB04h__RQRLonf8yFgXKA',
#    'plus_code': {'compound_code': 'GF28+MP Gaza',
#     'global_code': '8G3PGF28+MP'},
#    'reference': 'ChIJFxrB04h__RQRLonf8yFgXKA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'النصر، غزة'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5016951, 'lng': 34.4668445},
#     'viewport': {'northeast': {'lat': 31.50305333029149,
#       'lng': 34.4681848802915},
#      'southwest': {'lat': 31.50035536970849, 'lng': 34.4654869197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '42eef8a06516efb0e2ee577d233b1cbfd166a1c4',
#    'name': 'أبراج الفيروز',
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102556503340878269423">Halima Farra</a>'],
#      'photo_reference': 'CmRaAAAAt9P1C5BNrtSpDUmVfXELhjUZD6RSJOZec9neU2QoCCnX1tcTI5w_mWNrJcCbNtXkqFDrFUs0zfgaqNLFlZ0QhGYqlg_ips_8UK07ppnDwoLPeM_rgaQw2ZfeYcRP78gtEhAcLD1R7soE_cd8YF4EH0CJGhQ7UHH6zcM7s9e-RLuW-lB9wN4mkg',
#      'width': 1080}],
#    'place_id': 'ChIJPcRly51__RQRcns-tX7C8CM',
#    'plus_code': {'compound_code': 'GF28+MP Gaza',
#     'global_code': '8G3PGF28+MP'},
#    'rating': 3.5,
#    'reference': 'ChIJPcRly51__RQRcns-tX7C8CM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 13,
#    'vicinity': 'Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5084736, 'lng': 34.4661382},
#     'viewport': {'northeast': {'lat': 31.50977898029149,
#       'lng': 34.4675422802915},
#      'southwest': {'lat': 31.50708101970849, 'lng': 34.4648443197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '207754c274c088c58994f6073f2f88479461cb2b',
#    'name': 'HOLST CINTRE مركز هولست الثقافي',
#    'place_id': 'ChIJXUqPdHl__RQRlIyuW0y-v6U',
#    'plus_code': {'global_code': '8G3PGF58+9F'},
#    'reference': 'ChIJXUqPdHl__RQRlIyuW0y-v6U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.515598, 'lng': 34.4630797},
#     'viewport': {'northeast': {'lat': 31.5169635302915,
#       'lng': 34.4644182302915},
#      'southwest': {'lat': 31.5142655697085, 'lng': 34.4617202697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'd3544b8d5d9928be98f7384feab68c76a242b17a',
#    'name': 'Abu Skndr ابو اسكندر',
#    'opening_hours': {'open_now': True},
#    'place_id': 'ChIJ94ruJvx__RQRRTQQ8etUOVQ',
#    'plus_code': {'compound_code': 'GF87+66 Gaza',
#     'global_code': '8G3PGF87+66'},
#    'rating': 4,
#    'reference': 'ChIJ94ruJvx__RQRRTQQ8etUOVQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': 'شارع الصحابة مقابل جمعية الشابات المسلمات, منزل الحاج فوزي أبو ناصر, Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5046838, 'lng': 34.4506664},
#     'viewport': {'northeast': {'lat': 31.50601113029149,
#       'lng': 34.4520444302915},
#      'southwest': {'lat': 31.5033131697085, 'lng': 34.4493464697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '062b857d5e5922fb1286216a2e2470fed6e18f6d',
#    'name': 'منزل عوني الطويل',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109206058952121583417">منزل عوني الطويل</a>'],
#      'photo_reference': 'CmRaAAAApuPEW7xS5mP1ji38r91Sk1DKYOs1J107ZqjeTKSQuze9OL-ekwCwloQ2v2Z27PthNa8GOWUROW_hXq6k4M2I91qzh7YAMbWQqGT1PeOaPPjMuprHtdpfC1WnBnMJdoptEhA7syoK6GcvnbBGioA3_fkiGhSL4nsEKOtIJr0W4ECT5XYUz9TMGw',
#      'width': 1242}],
#    'place_id': 'ChIJtdzgoAR__RQRVMlA6SBP7z0',
#    'plus_code': {'compound_code': 'GF32+V7 Gaza',
#     'global_code': '8G3PGF32+V7'},
#    'rating': 4.8,
#    'reference': 'ChIJtdzgoAR__RQRVMlA6SBP7z0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': 'Al-Thalathini Street, Alsabra, Gaza, Gaza Strip, Israel., Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5240351, 'lng': 34.4635373},
#     'viewport': {'northeast': {'lat': 31.5254406802915,
#       'lng': 34.4648184302915},
#      'southwest': {'lat': 31.5227427197085, 'lng': 34.4621204697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'e89fa274bced959492670dee5f26681c5ff17476',
#    'name': 'منزل ابو رفيق مهنا',
#    'photos': [{'height': 450,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108517772867940572688">هايل ابوالحصين</a>'],
#      'photo_reference': 'CmRaAAAAZlPwCtA-EtF6nZogW52EPnDElyvtIAiPZda4LMhqMP8q_NFEWi8JE8HCK-pNA2Dr3Am7rKccN07WCfTJQeQY5Z_-9-A5KV_wx1OAlKOUJXN8ZMROSijXwWBV5GHPDh9qEhC_bHD5ZJ9X_9J0rlxa6wJtGhQ76PAClVHmjfuC5myiw2GL_pgU8w',
#      'width': 870}],
#    'place_id': 'ChIJ8fw0qJZ__RQRbKlm1Ut-3SU',
#    'plus_code': {'global_code': '8G3PGFF7+JC'},
#    'rating': 5,
#    'reference': 'ChIJ8fw0qJZ__RQRbKlm1Ut-3SU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'شارع الخندق, غزة'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.51872, 'lng': 34.4481792},
#     'viewport': {'northeast': {'lat': 31.5200416302915,
#       'lng': 34.4494960302915},
#      'southwest': {'lat': 31.51734366970851, 'lng': 34.4467980697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '0da2c455562fb982e03ec596d5b91ace74f5df26',
#    'name': 'شاليه الأضواء السياحي',
#    'place_id': 'ChIJD-VircJ__RQRFX5xShlOVDQ',
#    'plus_code': {'compound_code': 'GC9X+F7 Gaza',
#     'global_code': '8G3PGC9X+F7'},
#    'rating': 3.3,
#    'reference': 'ChIJD-VircJ__RQRFX5xShlOVDQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'الرمال, Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5228228, 'lng': 34.45327},
#     'viewport': {'northeast': {'lat': 31.52414973029151,
#       'lng': 34.4545925802915},
#      'southwest': {'lat': 31.52145176970851, 'lng': 34.4518946197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'e0d3d023262db3058541c2eab2e93d19525241a4',
#    'name': 'Alamal Hotel',
#    'place_id': 'ChIJK3aATAV__RQRQ6zbxdJB4Ag',
#    'plus_code': {'global_code': '8G3PGFF3+48'},
#    'rating': 4.7,
#    'reference': 'ChIJK3aATAV__RQRQ6zbxdJB4Ag',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'Omar Al-Mokhtar'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.4894708, 'lng': 34.439128},
#     'viewport': {'northeast': {'lat': 31.49084218029149,
#       'lng': 34.4405073302915},
#      'southwest': {'lat': 31.4881442197085, 'lng': 34.4378093697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '243afe78e9a23226d1ad4b8018fa96708bc6fad4',
#    'name': 'شاليه رويال هاوس',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1080,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107145550503023215894">شاليه رويال هاوس</a>'],
#      'photo_reference': 'CmRaAAAAzxlUHp2WEdHQ4i-h1GPETs7ZUoO7RJ9QkwLTW3no0ROZXCuoYFKL0Tq8UwuvoAg7OqIFVtfIY4m-Jj5RdZujqf8mvRjQnUBo8hUJuTJl9hdqbSvBVGggHmj-w7YbYq9ZEhB2rcOM9X-4IaNNFPWye3g1GhRjA2HRrMls2n-aVRV7PBWfrf8pBA',
#      'width': 1920}],
#    'place_id': 'ChIJHQYkYCiB_RQRXk4SD3B5poU',
#    'plus_code': {'compound_code': 'FCQQ+QM Gaza',
#     'global_code': '8G3PFCQQ+QM'},
#    'rating': 4.6,
#    'reference': 'ChIJHQYkYCiB_RQRXk4SD3B5poU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': 'مسجد علي بن أبي طالب جنوباً, Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5300487, 'lng': 34.47217910000001},
#     'viewport': {'northeast': {'lat': 31.5314054302915,
#       'lng': 34.4735193302915},
#      'southwest': {'lat': 31.5287074697085, 'lng': 34.4708213697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '71ded4ea30b5a79b568825edcdaf610d43eee880',
#    'name': 'ابراهيم محمد',
#    'place_id': 'ChIJb8Kn2ht__RQR_7OY44yCbEE',
#    'plus_code': {'global_code': '8G3PGFJC+2V'},
#    'reference': 'ChIJb8Kn2ht__RQR_7OY44yCbEE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Ahmedahmed, Zaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5255013, 'lng': 34.4493507},
#     'viewport': {'northeast': {'lat': 31.5268502802915,
#       'lng': 34.4506996802915},
#      'southwest': {'lat': 31.5241523197085, 'lng': 34.4480017197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '792bdd9f1ae817430cef18626ec14479c8ece9d5',
#    'name': 'عمارة شعت',
#    'place_id': 'ChIJpwrNSah__RQRYnc7LqMRpZY',
#    'plus_code': {'global_code': '8G3PGCGX+6P'},
#    'reference': 'ChIJpwrNSah__RQRYnc7LqMRpZY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'El naser, Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.52593220000001, 'lng': 34.4492556},
#     'viewport': {'northeast': {'lat': 31.5271631302915,
#       'lng': 34.4507407802915},
#      'southwest': {'lat': 31.5244651697085, 'lng': 34.4480428197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'ce86d6c62873db2b4931ef68e9835c984a5e0030',
#    'name': 'Andalus Tower',
#    'photos': [{'height': 3104,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116811900584877940610">Hala Ahmed</a>'],
#      'photo_reference': 'CmRZAAAAb3As_6ndACSyMP3os949APb_KFEsIlsVcLHrHnLy2AjvMRVSIOL18XRGr8CBg7DbxS8ETO2Lrt4C_Ej0Gcy39bxidTUzSCX9x7OIWDBLAagNCQ0lUvMeL-uyOJqmV3v2EhCrnfQS_WXGbbNs5epcZOfEGhRt3eNsBztrNJxChzpFhQsuJrMD3Q',
#      'width': 1746}],
#    'place_id': 'ChIJT04CtBt__RQRVhoFjv_aIo8',
#    'plus_code': {'global_code': '8G3PGCGX+9P'},
#    'rating': 4.2,
#    'reference': 'ChIJT04CtBt__RQRVhoFjv_aIo8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': 'Mohammed Kandeel, Giza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5319185, 'lng': 34.4710918},
#     'viewport': {'northeast': {'lat': 31.5332565302915,
#       'lng': 34.4724532802915},
#      'southwest': {'lat': 31.5305585697085, 'lng': 34.4697553197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '30157da72e208636d97e713a5fef6690fe41c127',
#    'name': 'قاعة الاميرة وردة للمناسبات',
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110142769814569257444">Motawea Nahed</a>'],
#      'photo_reference': 'CmRaAAAAARrngHXxT1ctegf9u28Nw7GsE6Hd-3VzKTVedFS-JHjiy0WjHDi58l3-Hxni_vGH4rQteeUPgt0k-uUwTdnrHwaBmnLlgDgku6nmJlrkrXTQIQm-kgfhXICgiLEuUGzFEhDEBxiiYwJv95_nddvfdoNZGhRXj5SWrDZa6IXk2FKRXiBtm5bNsw',
#      'width': 2322}],
#    'place_id': 'ChIJkXlbcfZ__RQR7OzqCLEWyt0',
#    'plus_code': {'global_code': '8G3PGFJC+QC'},
#    'rating': 5,
#    'reference': 'ChIJkXlbcfZ__RQR7OzqCLEWyt0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': 'نهاية شارع الجلاء، حي الشيخ رضوان، غزة،'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5355125, 'lng': 34.4679776},
#     'viewport': {'northeast': {'lat': 31.5368754302915,
#       'lng': 34.4693102302915},
#      'southwest': {'lat': 31.5341774697085, 'lng': 34.4666122697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '6988137487b92e514395b8650abdf1d5f7de7fe2',
#    'name': 'منزل أبناء المرحوم الشيخ حسن لبد',
#    'place_id': 'ChIJLTjA1TN__RQRlyeARNAL1pk',
#    'plus_code': {'global_code': '8G3PGFP9+65'},
#    'reference': 'ChIJLTjA1TN__RQRlyeARNAL1pk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'الشارع الثاني، غزة،'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5273331, 'lng': 34.4431857},
#     'viewport': {'northeast': {'lat': 31.5286386802915,
#       'lng': 34.4445010302915},
#      'southwest': {'lat': 31.5259407197085, 'lng': 34.4418030697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '92ae7739504754250326783c3bd3e07e49f8cdcf',
#    'name': 'Home',
#    'place_id': 'ChIJSY5nVTR__RQReKAdKht2_4o',
#    'plus_code': {'compound_code': 'GCGV+W7 Gaza',
#     'global_code': '8G3PGCGV+W7'},
#    'rating': 4.8,
#    'reference': 'ChIJSY5nVTR__RQReKAdKht2_4o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': 'Gaza'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.47287209999999, 'lng': 34.4972179},
#     'viewport': {'northeast': {'lat': 31.47422108029149,
#       'lng': 34.4985668802915},
#      'southwest': {'lat': 31.4715231197085, 'lng': 34.4958689197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '0b126c1042094ec150f2912aa7019ddf8bbf18be',
#    'name': 'Kibbutz Nahal Oz',
#    'place_id': 'ChIJCygfP8SB_RQRgDeXIPj0CfQ',
#    'plus_code': {'compound_code': 'FFFW+4V Nahal Oz, Israel',
#     'global_code': '8G3PFFFW+4V'},
#    'rating': 5,
#    'reference': 'ChIJCygfP8SB_RQRgDeXIPj0CfQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Unnamed Road, Nahal Oz'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 31.5151979, 'lng': 34.431847},
#     'viewport': {'northeast': {'lat': 31.51645543029149,
#       'lng': 34.4333357802915},
#      'southwest': {'lat': 31.51375746970849, 'lng': 34.4306378197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'a77ce0a9ada33798ce3fdb56d67fa1741951e34a',
#    'name': 'منزل أل الزميلي',
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107278515448268086477">مصطفى الزميلي</a>'],
#      'photo_reference': 'CmRaAAAAWOf9wDU5-D2oFdHHATt6rReaLvt5W9JX3i4jZXLjCx8HwvIjgUXLL3wBxd1BaiLnWfwBUe_x11rmoexSvHZe60tBw0FyYIrmMe5ve0_QaBCxj3LL1POPrNTomw3bFqxgEhAxsT1CgDIRRSbF0XzdX85MGhQRfruMapZ_DHI7F9GwHH4Mtcx62w',
#      'width': 4128}],
#    'place_id': 'ChIJL-IQRAJ__RQR65XpxU8azCY',
#    'plus_code': {'global_code': '8G3PGC8J+3P'},
#    'reference': 'ChIJL-IQRAJ__RQR65XpxU8azCY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'قطاع غزة, غزة'}],
#  'status': 'OK'}

# %%
hotel_df
# Out:
#                    City    Lat    Lon  Max Temp (F)  Humidity (%)  \
# 2       Tiznit Province  29.58  -9.50         71.40            59
# 12            Mahajanga -15.72  46.32         71.60            88
# 35       Zabul Province  32.25  67.25         73.04            18
# 66           Kiryat Gat  31.61  34.76         79.00            87
# 133          Nikolskoye  59.70  30.79         71.60            49
# 175              Boueni -12.90  45.08         75.20            83
# 202               Erzin  36.96  36.20         77.00            89
# 213         Mitsamiouli -11.38  43.28         77.74            78
# 304  Nizhniy Baskunchak  48.22  46.83         72.48            36
# 320                Wete  -5.06  39.73         74.77            86
# 429               Kumul  42.80  93.45         76.06            34
# 496                Gaza  31.50  34.47         79.00            69
#
#      Cloudiness (%)  Wind Speed (MPH) Country        Date  \
# 2                 0              3.49      MA  1593286215
# 12                0              2.24      MG  1593286216
# 35                0              8.12      AF  1593286218
# 66                0              4.43      IL  1593285627
# 133               0              4.47      RU  1593286232
# 175               0              8.05      YT  1593286237
# 202               0              0.54      TR  1593286241
# 213               0              5.48      KM  1593286242
# 304               0              6.44      RU  1593286253
# 320               0              8.28      TZ  1593286255
# 429               0              5.57      CN  1593286272
# 496               0              3.36      PS  1593286282
#
#                                Hotel Name
# 2
# 12   Restaurant Greedy Coco Lodge Majunga
# 35
# 66                               רגע בנחת
# 133               Tourist House - Sablino
# 175   Auberge bouloulou( inter djasmire )
# 202                          Artemis Otel
# 213                             Foyer ADM
# 304                           Arman hotel
# 320           Sharook Riviera Grand Lodge
# 429                      Laoyutang Resort
# 496            رابطة الفنانين الفلسطينيين

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lon"]]

# %%
# Add marker layer ontop of heat map
hotel_list = hotel_df["Hotel Name"]
# Create hotel symbol layer
hotel_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(150, 0, 0, 0.4)',
    stroke_color='rgba(0, 150, 0, 0.4)', scale=2,
    info_box_content=[f"Hotel: {hotel}" for hotel in hotel_list]
)


fig = gmaps.figure()
fig.add_layer(hotel_layer)



# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a combined map
fig = gmaps.figure()

fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
